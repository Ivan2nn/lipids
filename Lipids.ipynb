# %%
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
from  matplotlib.ticker import PercentFormatter
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import ks_2samp
from scipy.stats import ttest_ind
from scipy.stats import kruskal
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

import os
import json

with open('data/paths.json','r') as f:
    paths = json.load(f)

data_path = paths["data_path"]

# %% [markdown]
# <h1 style="color: red">Analysis of Brain Tissue Lipids Data</h1>

# %% [markdown]
# <p> The study is based on the following process:: we integrate the chromatographic peak for each lipid species to obtain the “area”. The peak area of the lipid species is then normalized to the internal standard (“IS Area”) to obtain the “area ratio”.  The area ratios are then normalized to the tissue weight of the original sample.</p>
# <p>
# The weight normalized area ratio of each lipid species in each sample was then used to create the pivot tables and perform statistical analysis. </p>

# %% [markdown]
# <h2>Preprocessing data</h2>

# %%
# importing file inside pandas dataframe

df = pd.read_excel(os.path.join(data_path,"20220228_Laezza_DRJ_Brain Tissue_ Lipids_raw data.xlsx"), skiprows=1)

# %%
df.head()
# Out:
#                        Sample Name Sample Name on Tube   Injection Volume  \
# 0  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S                10
# 1  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S                10
# 2  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S                10
# 3  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S                10
# 4  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S                10
#
#             Component Name      Mass Info                  IS Name  \
# 0  SM(18:1)+H_d9_SPLASH.IS  738.7 / 184.2                      NaN
# 1               SM(14:0)+H  675.5 / 184.1  SM(18:1)+H_d9_SPLASH.IS
# 2               SM(16:0)+H  703.6 / 184.1  SM(18:1)+H_d9_SPLASH.IS
# 3               SM(18:0)+H  731.6 / 184.1  SM(18:1)+H_d9_SPLASH.IS
# 4               SM(18:1)+H  729.6 / 184.1  SM(18:1)+H_d9_SPLASH.IS
#
#   Component Group Name  Expected RT          Area       IS Area  Area Ratio  \
# 0                   SM        12.51  6.142877e+07           NaN         NaN
# 1                   SM        12.51  4.116176e+06  6.142877e+07    0.067007
# 2                   SM        12.51  2.433723e+07  6.142877e+07    0.396186
# 3                   SM        12.51  1.432478e+08  6.142877e+07    2.331933
# 4                   SM        12.51  1.268323e+08  6.142877e+07    2.064706
#
#    Retention Time  Signal / Noise  Tissue Weight (mg)   Unnamed: 14  \
# 0       12.514791      141.426257                   56          NaN
# 1       12.737513       77.971430                   56     0.119656
# 2       12.662914      147.602022                   56     0.707475
# 3       12.580159      144.222304                   56     4.164166
# 4       12.572303      193.985512                   56     3.686974
#
#    Unnamed: 15       Unnamed: 16  Unnamed: 17
# 0          NaN               NaN          NaN
# 1          NaN  Scaling Factor:         100.0
# 2          NaN               NaN          NaN
# 3          NaN               NaN          NaN
# 4          NaN               NaN          NaN

# %%
# The subject label is composed of 3 sections: treatmentCode+subjectnumber sexCode tissueCode. There could be some problems in labeling (like white spaces) 
# so we need to be sure that all the labels are consistent. 
#
# 1) We remove the white spaces 
# 2) We relabel using the format treatmentCode+subjectnumber sexCode tissueCode

def organizeSampleName(label):
    label = label.replace(" ","")
    return label[0:3] + ' ' + label[3:5] + ' ' + label[5:]

df['Sample Name on Tube '] = df['Sample Name on Tube '].apply(lambda x: organizeSampleName(x))
df.head()
# Out:
#                        Sample Name Sample Name on Tube   Injection Volume  \
# 0  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S                10
# 1  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S                10
# 2  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S                10
# 3  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S                10
# 4  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S                10
#
#             Component Name      Mass Info                  IS Name  \
# 0  SM(18:1)+H_d9_SPLASH.IS  738.7 / 184.2                      NaN
# 1               SM(14:0)+H  675.5 / 184.1  SM(18:1)+H_d9_SPLASH.IS
# 2               SM(16:0)+H  703.6 / 184.1  SM(18:1)+H_d9_SPLASH.IS
# 3               SM(18:0)+H  731.6 / 184.1  SM(18:1)+H_d9_SPLASH.IS
# 4               SM(18:1)+H  729.6 / 184.1  SM(18:1)+H_d9_SPLASH.IS
#
#   Component Group Name  Expected RT          Area       IS Area  Area Ratio  \
# 0                   SM        12.51  6.142877e+07           NaN         NaN
# 1                   SM        12.51  4.116176e+06  6.142877e+07    0.067007
# 2                   SM        12.51  2.433723e+07  6.142877e+07    0.396186
# 3                   SM        12.51  1.432478e+08  6.142877e+07    2.331933
# 4                   SM        12.51  1.268323e+08  6.142877e+07    2.064706
#
#    Retention Time  Signal / Noise  Tissue Weight (mg)   Unnamed: 14  \
# 0       12.514791      141.426257                   56          NaN
# 1       12.737513       77.971430                   56     0.119656
# 2       12.662914      147.602022                   56     0.707475
# 3       12.580159      144.222304                   56     4.164166
# 4       12.572303      193.985512                   56     3.686974
#
#    Unnamed: 15       Unnamed: 16  Unnamed: 17
# 0          NaN               NaN          NaN
# 1          NaN  Scaling Factor:         100.0
# 2          NaN               NaN          NaN
# 3          NaN               NaN          NaN
# 4          NaN               NaN          NaN

# %%
PND_30 = ['C20 M1 S','C21 M1 S','C11 M4 S','C20 F1 S','C21 F1 S','C11 F1 S','T23 M1 S','T24 M2 S','T34 M2 S','T20 F1 S','T33 F2 S','T34 F2 S','C20 M1 C','C21 M1 C',
          'C11 M2 C','C20 F1 C','C21 F1 C','C11 F1 C','T23 M1 C','T24 M2 C','T34 M2 C','T20 F1 C','T33 F2 C','T34 F2 C']

# %%
df['PND'] = df['Sample Name on Tube '].apply(lambda x: 30 if x in PND_30 else 60)
df.tail()
# Out:
#                             Sample Name Sample Name on Tube   \
# 57259  08312021_JDR_FL_Lipid_Sample #48             T18 F2 C
# 57260  08312021_JDR_FL_Lipid_Sample #48             T18 F2 C
# 57261  08312021_JDR_FL_Lipid_Sample #48             T18 F2 C
# 57262  08312021_JDR_FL_Lipid_Sample #48             T18 F2 C
# 57263  08312021_JDR_FL_Lipid_Sample #48             T18 F2 C
#
#        Injection Volume Component Name      Mass Info  \
# 57259                10            EPA  301.0 / 257.0
# 57260                10            DHA  327.0 / 283.0
# 57261                10            DPA  329.0 / 285.0
# 57262                10   Adrenic Acid  331.0 / 287.0
# 57263                10             AA  303.0 / 259.0
#
#                                    IS Name Component Group Name  Expected RT  \
# 57259  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                 PUFA         2.65
# 57260  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                 PUFA         2.82
# 57261  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                 PUFA         2.80
# 57262  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                 PUFA         2.79
# 57263  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                 PUFA         2.81
#
#                Area       IS Area  Area Ratio  Retention Time  Signal / Noise  \
# 57259  9.494550e+05  429984.07819    2.208117        2.722196       70.891580
# 57260  1.502219e+08  429984.07819  349.366103        2.558918      284.097687
# 57261  1.058937e+07  429984.07819   24.627343        2.543228      176.422195
# 57262  1.978464e+06  429984.07819    4.601250        2.563011       83.911044
# 57263  1.463774e+08  429984.07819  340.425180        2.559217      270.128505
#
#        Tissue Weight (mg)   Unnamed: 14  Unnamed: 15 Unnamed: 16  Unnamed: 17  \
# 57259                   40     5.520292          NaN         NaN          NaN
# 57260                   40   873.415258          NaN         NaN          NaN
# 57261                   40    61.568359          NaN         NaN          NaN
# 57262                   40    11.503124          NaN         NaN          NaN
# 57263                   40   851.062950          NaN         NaN          NaN
#
#        PND
# 57259   60
# 57260   60
# 57261   60
# 57262   60
# 57263   60

# %%
# number of rows and columns

df.shape
# Out:
# (57264, 19)

# %%
# titles of the columns

print(df.columns.values)
# Out:
# ['Sample Name' 'Sample Name on Tube ' 'Injection Volume' 'Component Name'
#  'Mass Info' 'IS Name' 'Component Group Name' 'Expected RT' 'Area'
#  'IS Area' 'Area Ratio' 'Retention Time' 'Signal / Noise'
#  'Tissue Weight (mg) ' 'Unnamed: 14' 'Unnamed: 15' 'Unnamed: 16'
#  'Unnamed: 17' 'PND']

# %%
# last column is the 'Unnamed: 14' which actually is the Normalized Area ratio (( Area ratio ÷ tissue weight)* scaling factor)

df.rename(columns={'Unnamed: 14':'Normalized Area'}, inplace=True)

# %%
# unique subjects

len(df['Sample Name'].unique())
# Out:
# 48

# %%
# The Treatment group is identified by the first character on the "Sample Name on Tube" column: (C) for Control (T) for Deltamethrin

df.insert(2,'Treatment',['Control' if x[0] == 'C' else 'Deltamethrin' for x in df.iloc[:,1]])

# %%
df.head()
# Out:
#                        Sample Name Sample Name on Tube  Treatment  \
# 0  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Control
# 1  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Control
# 2  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Control
# 3  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Control
# 4  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Control
#
#    Injection Volume           Component Name      Mass Info  \
# 0                10  SM(18:1)+H_d9_SPLASH.IS  738.7 / 184.2
# 1                10               SM(14:0)+H  675.5 / 184.1
# 2                10               SM(16:0)+H  703.6 / 184.1
# 3                10               SM(18:0)+H  731.6 / 184.1
# 4                10               SM(18:1)+H  729.6 / 184.1
#
#                    IS Name Component Group Name  Expected RT          Area  \
# 0                      NaN                   SM        12.51  6.142877e+07
# 1  SM(18:1)+H_d9_SPLASH.IS                   SM        12.51  4.116176e+06
# 2  SM(18:1)+H_d9_SPLASH.IS                   SM        12.51  2.433723e+07
# 3  SM(18:1)+H_d9_SPLASH.IS                   SM        12.51  1.432478e+08
# 4  SM(18:1)+H_d9_SPLASH.IS                   SM        12.51  1.268323e+08
#
#         IS Area  Area Ratio  Retention Time  Signal / Noise  \
# 0           NaN         NaN       12.514791      141.426257
# 1  6.142877e+07    0.067007       12.737513       77.971430
# 2  6.142877e+07    0.396186       12.662914      147.602022
# 3  6.142877e+07    2.331933       12.580159      144.222304
# 4  6.142877e+07    2.064706       12.572303      193.985512
#
#    Tissue Weight (mg)   Normalized Area  Unnamed: 15       Unnamed: 16  \
# 0                   56              NaN          NaN               NaN
# 1                   56         0.119656          NaN  Scaling Factor:
# 2                   56         0.707475          NaN               NaN
# 3                   56         4.164166          NaN               NaN
# 4                   56         3.686974          NaN               NaN
#
#    Unnamed: 17  PND
# 0          NaN   30
# 1        100.0   30
# 2          NaN   30
# 3          NaN   30
# 4          NaN   30

# %%
# The Sex group is identified by the fifth character on the "Sample Name on Tube" column: (M) for Male (F) for Female
# If the subject labeling modality will chage, the following code must be adapted

df.insert(2,'Gender',['Male' if x[4] == 'M' else 'Female' for x in df.iloc[:,1]])

# %%
df.head()
# Out:
#                        Sample Name Sample Name on Tube  Gender Treatment  \
# 0  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 1  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 2  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 3  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 4  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
#
#    Injection Volume           Component Name      Mass Info  \
# 0                10  SM(18:1)+H_d9_SPLASH.IS  738.7 / 184.2
# 1                10               SM(14:0)+H  675.5 / 184.1
# 2                10               SM(16:0)+H  703.6 / 184.1
# 3                10               SM(18:0)+H  731.6 / 184.1
# 4                10               SM(18:1)+H  729.6 / 184.1
#
#                    IS Name Component Group Name  Expected RT  ...  \
# 0                      NaN                   SM        12.51  ...
# 1  SM(18:1)+H_d9_SPLASH.IS                   SM        12.51  ...
# 2  SM(18:1)+H_d9_SPLASH.IS                   SM        12.51  ...
# 3  SM(18:1)+H_d9_SPLASH.IS                   SM        12.51  ...
# 4  SM(18:1)+H_d9_SPLASH.IS                   SM        12.51  ...
#
#         IS Area  Area Ratio  Retention Time  Signal / Noise  \
# 0           NaN         NaN       12.514791      141.426257
# 1  6.142877e+07    0.067007       12.737513       77.971430
# 2  6.142877e+07    0.396186       12.662914      147.602022
# 3  6.142877e+07    2.331933       12.580159      144.222304
# 4  6.142877e+07    2.064706       12.572303      193.985512
#
#    Tissue Weight (mg)   Normalized Area  Unnamed: 15       Unnamed: 16  \
# 0                   56              NaN          NaN               NaN
# 1                   56         0.119656          NaN  Scaling Factor:
# 2                   56         0.707475          NaN               NaN
# 3                   56         4.164166          NaN               NaN
# 4                   56         3.686974          NaN               NaN
#
#   Unnamed: 17  PND
# 0         NaN   30
# 1       100.0   30
# 2         NaN   30
# 3         NaN   30
# 4         NaN   30
#
# [5 rows x 21 columns]

# %%
# The Tissue group is identified by the last character on the "Sample Name on Tube" column: (M) for Male (F) for Female
# If the subject labeling modality will chage, the following code must be adapted

df.insert(4,'Tissue',['Cortex' if x[-1] == 'C' else 'Striatum' for x in df.iloc[:,1]])

# %%
df.head()
# Out:
#                        Sample Name Sample Name on Tube  Gender Treatment  \
# 0  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 1  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 2  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 3  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 4  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
#
#      Tissue  Injection Volume           Component Name      Mass Info  \
# 0  Striatum                10  SM(18:1)+H_d9_SPLASH.IS  738.7 / 184.2
# 1  Striatum                10               SM(14:0)+H  675.5 / 184.1
# 2  Striatum                10               SM(16:0)+H  703.6 / 184.1
# 3  Striatum                10               SM(18:0)+H  731.6 / 184.1
# 4  Striatum                10               SM(18:1)+H  729.6 / 184.1
#
#                    IS Name Component Group Name  ...       IS Area  \
# 0                      NaN                   SM  ...           NaN
# 1  SM(18:1)+H_d9_SPLASH.IS                   SM  ...  6.142877e+07
# 2  SM(18:1)+H_d9_SPLASH.IS                   SM  ...  6.142877e+07
# 3  SM(18:1)+H_d9_SPLASH.IS                   SM  ...  6.142877e+07
# 4  SM(18:1)+H_d9_SPLASH.IS                   SM  ...  6.142877e+07
#
#    Area Ratio  Retention Time  Signal / Noise  Tissue Weight (mg)   \
# 0         NaN       12.514791      141.426257                   56
# 1    0.067007       12.737513       77.971430                   56
# 2    0.396186       12.662914      147.602022                   56
# 3    2.331933       12.580159      144.222304                   56
# 4    2.064706       12.572303      193.985512                   56
#
#    Normalized Area  Unnamed: 15       Unnamed: 16  Unnamed: 17 PND
# 0              NaN          NaN               NaN          NaN  30
# 1         0.119656          NaN  Scaling Factor:         100.0  30
# 2         0.707475          NaN               NaN          NaN  30
# 3         4.164166          NaN               NaN          NaN  30
# 4         3.686974          NaN               NaN          NaN  30
#
# [5 rows x 22 columns]

# %%
# Extract sample name
df['sample Name'] = df['Sample Name on Tube '].apply(lambda x: x[1:3])

# %%
# Identify normalization factor
df['is Normalization Factor'] = df['Component Name'].apply(lambda x: "_SPLASH.IS" in x)

# %%
# Assign normalization factor

le = LabelEncoder()
le.fit(df[['IS Name', 'Component Name']].values.flatten().ravel())
df['normFactor'] = le.transform(df['IS Name'])
df['normFactor'] = df.apply(lambda x: 
        x['normFactor'] if not x['is Normalization Factor'] else
        le.transform(np.asarray([x['Component Name']]))[0], axis=1)
df['normFactor'] = le.fit_transform(df['normFactor'])

# %%
# Let's check if there are NaN values in the 3 new columns. If there are NaN values the relabelling process is incorrect

print(df['Gender'].isnull().values.any())
print(df['Treatment'].isnull().values.any())
print(df['Tissue'].isnull().values.any())
print(df['PND'].isnull().values.any())
# Out:
# False
# False
# False
# False

# %%
# There are other columns which present NaN values; 
# The column that we called 'Normalized Area' has some N/A values... 

print(df['Normalized Area'].isnull().values.sum())
# Out:
# 25897

# %%
# Numbers of unique components

len(df['Component Name'].unique())
# Out:
# 1193

# %%
# Number of group components

len(df['Component Group Name'].unique())
# Out:
# 23

# %%
# Let's consider only rows where Normalized Area is not null

df_clean = df.dropna(subset=['Normalized Area'])
print(df_clean['Normalized Area'].isnull().values.sum())
# Out:
# 0

# %%
# Numbers of unique components in the dataframe without null values

len(df_clean['Component Name'].unique())
# Out:
# 800

# %%
list_of_component_groups = df_clean['Component Group Name'].unique().tolist()

# %%
df.head(30)
# Out:
#                         Sample Name Sample Name on Tube  Gender Treatment  \
# 0   08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 1   08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 2   08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 3   08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 4   08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 5   08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 6   08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 7   08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 8   08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 9   08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 10  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 11  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 12  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 13  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 14  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 15  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 16  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 17  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 18  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 19  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 20  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 21  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 22  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 23  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 24  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 25  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 26  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 27  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 28  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
# 29  08312021_JDR_FL_Lipid_Sample #1             C20 M1 S   Male   Control
#
#       Tissue  Injection Volume           Component Name      Mass Info  \
# 0   Striatum                10  SM(18:1)+H_d9_SPLASH.IS  738.7 / 184.2
# 1   Striatum                10               SM(14:0)+H  675.5 / 184.1
# 2   Striatum                10               SM(16:0)+H  703.6 / 184.1
# 3   Striatum                10               SM(18:0)+H  731.6 / 184.1
# 4   Striatum                10               SM(18:1)+H  729.6 / 184.1
# 5   Striatum                10               SM(20:0)+H  759.6 / 184.1
# 6   Striatum                10               SM(20:1)+H  757.6 / 184.1
# 7   Striatum                10               SM(22:0)+H  787.7 / 184.1
# 8   Striatum                10               SM(22:1)+H  785.7 / 184.1
# 9   Striatum                10               SM(24:0)+H  815.7 / 184.1
# 10  Striatum                10               SM(24:1)+H  813.7 / 184.1
# 11  Striatum                10               SM(26:0)+H  843.7 / 184.1
# 12  Striatum                10               SM(26:1)+H  841.7 / 184.1
# 13  Striatum                10  CE(18:1)+H_d7_SPLASH.IS  675.2 / 369.4
# 14  Striatum                10               CE(24:0)+H  754.7 / 369.4
# 15  Striatum                10               CE(22:6)+H  714.6 / 369.4
# 16  Striatum                10               CE(20:0)+H  698.7 / 369.4
# 17  Striatum                10               CE(20:1)+H  696.7 / 369.4
# 18  Striatum                10               CE(22:5)+H  716.6 / 369.4
# 19  Striatum                10               CE(14:0)+H  614.6 / 369.4
# 20  Striatum                10               CE(16:0)+H  642.6 / 369.4
# 21  Striatum                10               CE(16:1)+H  640.6 / 369.4
# 22  Striatum                10               CE(18:0)+H  670.6 / 369.4
# 23  Striatum                10               CE(18:1)+H  668.6 / 369.4
# 24  Striatum                10               CE(18:2)+H  666.6 / 369.4
# 25  Striatum                10               CE(18:3)+H  664.6 / 369.4
# 26  Striatum                10               CE(20:2)+H  694.6 / 369.4
# 27  Striatum                10               CE(20:3)+H  692.6 / 369.4
# 28  Striatum                10               CE(20:4)+H  690.6 / 369.4
# 29  Striatum                10               CE(20:5)+H  688.6 / 369.4
#
#                                 IS Name Component Group Name  ...  \
# 0                                   NaN                   SM  ...
# 1               SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 2               SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 3               SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 4               SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 5               SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 6               SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 7               SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 8               SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 9               SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 10              SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 11              SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 12              SM(18:1)+H_d9_SPLASH.IS                   SM  ...
# 13                                  NaN                   CE  ...
# 14  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 15  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 16  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 17  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 18  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 19  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 20  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 21  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 22  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 23  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 24  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 25  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 26  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 27  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 28  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
# 29  TAG(15:0/18:1/15:0)+NH4d7_SPLASH.IS                   CE  ...
#
#     Signal / Noise  Tissue Weight (mg)   Normalized Area  Unnamed: 15  \
# 0       141.426257                   56              NaN          NaN
# 1        77.971430                   56         0.119656          NaN
# 2       147.602022                   56         0.707475          NaN
# 3       144.222304                   56         4.164166          NaN
# 4       193.985512                   56         3.686974          NaN
# 5        33.866885                   56         0.157538          NaN
# 6       154.944122                   56         0.187413          NaN
# 7              NaN                   56              NaN          NaN
# 8        11.337270                   56         0.130623          NaN
# 9        29.639917                   56         0.192052          NaN
# 10       55.161076                   56         0.620138          NaN
# 11       13.762644                   56         0.034619          NaN
# 12             NaN                   56              NaN          NaN
# 13             NaN                   56              NaN          NaN
# 14             NaN                   56              NaN          NaN
# 15       10.793051                   56         0.094349          NaN
# 16             NaN                   56              NaN          NaN
# 17             NaN                   56              NaN          NaN
# 18             NaN                   56              NaN          NaN
# 19        4.106624                   56         0.026346          NaN
# 20             NaN                   56              NaN          NaN
# 21        8.322095                   56         0.044568          NaN
# 22        4.772906                   56         0.064699          NaN
# 23       19.448863                   56         0.087223          NaN
# 24             NaN                   56              NaN          NaN
# 25             NaN                   56              NaN          NaN
# 26             NaN                   56              NaN          NaN
# 27        4.492056                   56         0.029455          NaN
# 28        7.822321                   56         0.016718          NaN
# 29       10.385585                   56         0.066214          NaN
#
#          Unnamed: 16  Unnamed: 17  PND  sample Name  is Normalization Factor  \
# 0                NaN          NaN   30           20                     True
# 1   Scaling Factor:         100.0   30           20                    False
# 2                NaN          NaN   30           20                    False
# 3                NaN          NaN   30           20                    False
# 4                NaN          NaN   30           20                    False
# 5                NaN          NaN   30           20                    False
# 6                NaN          NaN   30           20                    False
# 7                NaN          NaN   30           20                    False
# 8                NaN          NaN   30           20                    False
# 9                NaN          NaN   30           20                    False
# 10               NaN          NaN   30           20                    False
# 11               NaN          NaN   30           20                    False
# 12               NaN          NaN   30           20                    False
# 13               NaN          NaN   30           20                     True
# 14               NaN          NaN   30           20                    False
# 15               NaN          NaN   30           20                    False
# 16               NaN          NaN   30           20                    False
# 17               NaN          NaN   30           20                    False
# 18               NaN          NaN   30           20                    False
# 19               NaN          NaN   30           20                    False
# 20               NaN          NaN   30           20                    False
# 21               NaN          NaN   30           20                    False
# 22               NaN          NaN   30           20                    False
# 23               NaN          NaN   30           20                    False
# 24               NaN          NaN   30           20                    False
# 25               NaN          NaN   30           20                    False
# 26               NaN          NaN   30           20                    False
# 27               NaN          NaN   30           20                    False
# 28               NaN          NaN   30           20                    False
# 29               NaN          NaN   30           20                    False
#
#    normFactor
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         10
# 11         10
# 12         10
# 13          0
# 14         11
# 15         11
# 16         11
# 17         11
# 18         11
# 19         11
# 20         11
# 21         11
# 22         11
# 23         11
# 24         11
# 25         11
# 26         11
# 27         11
# 28         11
# 29         11
#
# [30 rows x 25 columns]

# %%
# Drop unnecessary columns 

df.drop(columns=['Sample Name', 'Unnamed: 15', 
    'Unnamed: 16', 'Unnamed: 17', 'IS Name'
    ], inplace=True)

# %%
# Change column names to camelCase
cn = df.columns
cn_camelCase = [x.title().replace('/','').replace(' ','').replace('(','').replace(')','') for x in cn]
cn_camelCase = [''.join([x[0].lower(), x[1:]]) for x in cn_camelCase]
df.columns = cn_camelCase

# %%
# Save dataframe to data_path

df.to_csv(os.path.join(data_path, 'clean_data.csv'), index=False)
